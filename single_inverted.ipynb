# %%
######### Basics #########
import numpy as np
import matplotlib.pyplot as plt
from random import randint
import time as time
######### LinAlg #########
import scipy.sparse as spr
from scipy.sparse.linalg import spsolve
import pypardiso as pypa
######### Animation #########
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
import matplotlib.animation as animation
######### Acceleration #########
from numba import njit
import jax.numpy as jnp
from jax import grad, jit, vmap
from functools import partial
import jax.random as jr
import jax

# %%
from test import f_test
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/1f/534tfd7n7tz0l9g3f2ltwx2w0000gp/T/ipykernel_52458/2176441777.py in <module>
# ----> 1 from test import f_test
#
# ImportError: cannot import name 'f_test' from 'test' (/Users/frederik/Documents/OneDrive - Københavns Universitet/NumericalMethods/test.py)

# %%
a = jnp.arange(5)
f_test(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/1f/534tfd7n7tz0l9g3f2ltwx2w0000gp/T/ipykernel_52458/2297914457.py in <module>
#       1 a = jnp.arange(5)
# ----> 2 f_test(a)
#
# NameError: name 'f_test' is not defined
